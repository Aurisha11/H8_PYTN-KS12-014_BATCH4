# %% [markdown]
# IMPORT LIBRARY PANDAS DAN NUMPY

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# IMPORT LIBRARY MATPLOTLIB

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Membaca File CSV dengan Library Pandas

# %%
df = pd.read_csv("london_crime_by_lsoa.csv")
df
# Out:
#         lsoa_code     borough               major_category  \
# 0       E01001116     Croydon                     Burglary
# 1       E01001646   Greenwich  Violence Against the Person
# 2       E01000677     Bromley  Violence Against the Person
# 3       E01003774   Redbridge                     Burglary
# 4       E01004563  Wandsworth                      Robbery
# ...           ...         ...                          ...
# 121358  E01000461      Bexley           Theft and Handling
# 121359  E01001305      Ealing                        Drugs
# 121360  E01001433     Enfield              Criminal Damage
# 121361  E01000657     Bromley           Theft and Handling
# 121362  E01000578       Brent                     Burglary
#
#                                 minor_category  value    year  month
# 0                  Burglary in Other Buildings    0.0  2016.0   11.0
# 1                               Other violence    0.0  2016.0   11.0
# ...

# %% [markdown]
# Menampilkan 5 Data teratas

# %%
df.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value    year  month
# 0  Burglary in Other Buildings    0.0  2016.0   11.0
# 1               Other violence    0.0  2016.0   11.0
# 2               Other violence    0.0  2015.0    5.0
# 3  Burglary in Other Buildings    0.0  2016.0    3.0
# 4            Personal Property    0.0  2008.0    6.0

# %% [markdown]
# Menampilkan 5 Data terakhir

# %%
df.tail()
# Out:
#         lsoa_code  borough      major_category  \
# 121358  E01000461   Bexley  Theft and Handling
# 121359  E01001305   Ealing               Drugs
# 121360  E01001433  Enfield     Criminal Damage
# 121361  E01000657  Bromley  Theft and Handling
# 121362  E01000578    Brent            Burglary
#
#                                 minor_category  value    year  month
# 121358           Theft/Taking Of Motor Vehicle    0.0  2014.0    1.0
# 121359                        Drug Trafficking    0.0  2015.0   11.0
# 121360        Criminal Damage To Motor Vehicle    0.0  2014.0   10.0
# 121361  Motor Vehicle Interference & Tampering    0.0  2015.0    8.0
# 121362                     Burglary in a Dwell    NaN     NaN    NaN

# %% [markdown]
# Menampilkan Index dari Dataset CSV

# %%
df.index
# Out:
# RangeIndex(start=0, stop=121363, step=1)

# %%
df.index.values
# Out:
# array([     0,      1,      2, ..., 121360, 121361, 121362], dtype=int64)

# %% [markdown]
# Melihat Tipe Data

# %%
df.info
# Out:
# <bound method DataFrame.info of         lsoa_code     borough               major_category  \
# 0       E01001116     Croydon                     Burglary
# 1       E01001646   Greenwich  Violence Against the Person
# 2       E01000677     Bromley  Violence Against the Person
# 3       E01003774   Redbridge                     Burglary
# 4       E01004563  Wandsworth                      Robbery
# ...           ...         ...                          ...
# 121358  E01000461      Bexley           Theft and Handling
# 121359  E01001305      Ealing                        Drugs
# 121360  E01001433     Enfield              Criminal Damage
# 121361  E01000657     Bromley           Theft and Handling
# 121362  E01000578       Brent                     Burglary
#
#                                 minor_category  value    year  month
# 0                  Burglary in Other Buildings    0.0  2016.0   11.0
# 1                               Other violence    0.0  2016.0   11.0
# ...

# %% [markdown]
# Menampilkan Statistik singkat dari Dataset

# %%
df.describe()
# Out:
#                value           year          month
# count  121362.000000  121362.000000  121362.000000
# mean        0.475684    2011.993169       6.479541
# std         1.629562       2.583128       3.442921
# min         0.000000    2008.000000       1.000000
# 25%         0.000000    2010.000000       3.000000
# 50%         0.000000    2012.000000       6.000000
# 75%         1.000000    2014.000000       9.000000
# max       122.000000    2016.000000      12.000000

# %% [markdown]
# Merubah kolom borough menjadi country

# %%
df.rename(columns={'borough':'country'}, inplace=True)
df.head()
# Out:
#    lsoa_code     country               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value    year  month
# 0  Burglary in Other Buildings    0.0  2016.0   11.0
# 1               Other violence    0.0  2016.0   11.0
# 2               Other violence    0.0  2015.0    5.0
# 3  Burglary in Other Buildings    0.0  2016.0    3.0
# 4            Personal Property    0.0  2008.0    6.0

# %% [markdown]
# Melakukan Slicing terhadap Kolom yang dipakai

# %%
df_country = df.loc[:,['country','major_category','minor_category','year','value']]
df_country.head()
# Out:
#       country               major_category               minor_category  \
# 0     Croydon                     Burglary  Burglary in Other Buildings
# 1   Greenwich  Violence Against the Person               Other violence
# 2     Bromley  Violence Against the Person               Other violence
# 3   Redbridge                     Burglary  Burglary in Other Buildings
# 4  Wandsworth                      Robbery            Personal Property
#
#      year  value
# 0  2016.0    0.0
# 1  2016.0    0.0
# 2  2015.0    0.0
# 3  2016.0    0.0
# 4  2008.0    0.0

# %% [markdown]
# Melihat data kasus crime per country

# %%
df_summed = df_country.groupby(['country'], as_index=False)['value'].sum()
df_summed
# Out:
#                    country   value
# 0     Barking and Dagenham  1321.0
# 1                   Barnet  1912.0
# 2                   Bexley  1053.0
# 3                    Brent  2014.0
# 4                  Bromley  1467.0
# 5                   Camden  2542.0
# 6           City of London     6.0
# 7                  Croydon  2521.0
# 8                   Ealing  2286.0
# 9                  Enfield  1763.0
# 10               Greenwich  1586.0
# 11                 Hackney  1889.0
# 12  Hammersmith and Fulham  1527.0
# 13                Haringey  2024.0
# 14                  Harrow  1058.0
# 15                Havering  1232.0
# 16              Hillingdon  2020.0
# 17                Hounslow  1516.0
# 18               Islington  2074.0
# 19  Kensington and Chelsea  1418.0
# 20    Kingston upon Thames   650.0
# 21                 Lambeth  2698.0
# 22                Lewisham  1965.0
# 23                  Merton  1043.0
# 24                  Newham  2290.0
# 25               Redbridge  1684.0
# ...

# %% [markdown]
# Melihat kasus crime per tahun (major_catogory + minor_catogpry)

# %%
df_sum_year = df.groupby(['year'], as_index=False)['value'].sum()
df_sum_year
# Out:
#      year   value
# 0  2008.0  6588.0
# 1  2009.0  6159.0
# 2  2010.0  6204.0
# 3  2011.0  6851.0
# 4  2012.0  6752.0
# 5  2013.0  6152.0
# 6  2014.0  5993.0
# 7  2015.0  6346.0
# 8  2016.0  6685.0

# %% [markdown]
# Menampilkan Line Plot

# %%
df_sum_year.set_index('year').plot(kind='line', figsize=(8,6), color='red', linewidth='2')
plt.title('LONDON CRIME 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# - Terlihat dari Line Plot di atas Tahun 2012 - 2014 mengalami penurunan, dan Pada Tahun 2014 - 2016 mengalami kenaikan yang signifikan

# %% [markdown]
# Melihat Jumlah Crime terkecil

# %%
df_sum_year.min()
# Out:
# year     2008.0
# value    5993.0
# dtype: float64

# %% [markdown]
# Melihat Jumlah Crime terbesar

# %%
df_sum_year.max()
# Out:
# year     2016.0
# value    6851.0
# dtype: float64

# %% [markdown]
# Menampilkan data dari country

# %%
# melihat area brent
Westminster = df[(df['country']=='Westminster')]
Westminster
# Out:
#         lsoa_code      country               major_category  \
# 21      E01004660  Westminster           Theft and Handling
# 46      E01004678  Westminster              Criminal Damage
# 74      E01032513  Westminster  Violence Against the Person
# 134     E01004674  Westminster           Theft and Handling
# 165     E01004677  Westminster           Theft and Handling
# ...           ...          ...                          ...
# 121072  E01004662  Westminster    Other Notifiable Offences
# 121085  E01004665  Westminster           Theft and Handling
# 121156  E01004659  Westminster           Theft and Handling
# 121195  E01033599  Westminster  Violence Against the Person
# 121286  E01004735  Westminster                        Drugs
#
#                                 minor_category  value    year  month
# 21                       Handling Stolen Goods    0.0  2012.0    2.0
# 46                       Other Criminal Damage    0.0  2008.0   11.0
# ...

# %%
df_Westminster = Westminster[(Westminster['year'] > 2007)].groupby(['year'])['value'].sum()
df_Westminster
# Out:
# year
# 2008.0    360.0
# 2009.0    242.0
# 2010.0    231.0
# 2011.0    593.0
# 2012.0    682.0
# 2013.0    616.0
# 2014.0    296.0
# 2015.0    452.0
# 2016.0    358.0
# Name: value, dtype: float64

# %% [markdown]
# Menampilkan Line Plot Crime Country Barnet dari Tahun 2008 - 2016

# %%
df_Westminster.plot(kind='line', figsize=(30,5), color='red', linewidth='2')
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('LONDON CRIME 2008 - 2016')
plt.show()

# %% [markdown]
# - Terlihat dari Line Plot di atas Tahun 2012 adalah puncak dari jumlah kasus crime di London

# %% [markdown]
# Menampilkan top 5 country dengan jumlah crime tertinggi

# %%
df_summed_sorted = df_summed.sort_values(by='value', ascending=False)
df_summed_sorted.head(5)
# Out:
#         country   value
# 32  Westminster  3830.0
# 21      Lambeth  2698.0
# 5        Camden  2542.0
# 27    Southwark  2532.0
# 7       Croydon  2521.0

# %%
df_top5 = df_summed_sorted.head(5)
df_top5.set_index('country', inplace = True)
df_top5
# Out:
#               value
# country
# Westminster  3830.0
# Lambeth      2698.0
# Camden       2542.0
# Southwark    2532.0
# Croydon      2521.0

# %% [markdown]
# Menampilkan Area Plot dari top 5 country dengan value crime tertinggi

# %%
mpl.style.use(['ggplot'])
df_top5.plot(kind = 'area',
             stacked = False,
             figsize=(12,4),)
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# - Dari Area plot ditunjukan bahwa kota WEstminster merupakan kota dengan jumlah kasus kriminal tertinggi selama tahun 2008 - 2016

# %% [markdown]
# Menampilkan area plot major-category pada country Westminster

# %%
df_Westminster_areaPlot = Westminster[(Westminster['year'] > 2007)].groupby(['major_category','year'])['value'].sum()
df_Westminster_areaPlot.plot(kind='area', figsize=(30,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Major Category Area Westminster 2008-2016')
plt.show()

# %% [markdown]
# - Terlihat bahwa dar ndata major catehory untuk kota Westminster kasus yang sering terjadi pada Theft and Handling.

# %% [markdown]
# Menampilkan area plot minor-category pada country Westminster

# %%
df_Westminster_areaPlot = Westminster[(Westminster['year'] > 2007)].groupby(['minor_category','year'])['value'].sum()
df_Westminster_areaPlot.plot(kind='area', figsize=(30,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Minor Category Area Westminster 2008-2016')
plt.show()

# %% [markdown]
# - Terlihat bahwa dari data minor category untuk kota Westminster kasus yang sering terjadi adalah other Theft Person

# %% [markdown]
# Menampilkan Major_Category = Roberry dari Tahun 2008 - 2016

# %%
major = df[(df['year'] > 2007)].groupby(['major_category','year'])['value'].sum()
robbery = major['Robbery']
robbery
df_robbery = robbery.to_frame()
df_robbery = df_robbery.rename(columns={'value': 'Robbery'})
df_robbery
# Out:
#         Robbery
# year
# 2008.0    334.0
# 2009.0    259.0
# 2010.0    269.0
# 2011.0    355.0
# 2012.0    323.0
# 2013.0    280.0
# 2014.0    201.0
# 2015.0    161.0
# 2016.0    186.0

# %%
burglary = major['Burglary']
burglary
df_burglary = burglary.to_frame()
df_burglary = df_burglary.rename(columns={'value': 'Burglary'})
df_burglary
# Out:
#         Burglary
# year
# 2008.0     824.0
# 2009.0     816.0
# 2010.0     790.0
# 2011.0     909.0
# 2012.0     879.0
# 2013.0     807.0
# 2014.0     723.0
# 2015.0     594.0
# 2016.0     649.0

# %% [markdown]
# Menggabungkan 2 data frame

# %%
df_burglary_robbery = pd.concat([df_robbery, df_burglary], axis=1)
df_burglary_robbery
# Out:
#         Robbery  Burglary
# year
# 2008.0    334.0     824.0
# 2009.0    259.0     816.0
# 2010.0    269.0     790.0
# 2011.0    355.0     909.0
# 2012.0    323.0     879.0
# 2013.0    280.0     807.0
# 2014.0    201.0     723.0
# 2015.0    161.0     594.0
# 2016.0    186.0     649.0

# %% [markdown]
# Menampilkan Area Plot perbandingan Burlgary dan Robbery dari Tahun 2008 - 2016

# %%
df_burglary_robbery.plot(kind='area', alpha=0.35, figsize=(10,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Burglary and Robbery in London 2008 - 2016')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa hasil compare dari Burglary vs Robbery, selama tahun 2008 - 2016 Burglary masih jadi trend kasus crime di london</span>.

# %%
df_burglary_robbery.plot(kind='hist')
plt.title("histogram of Burglary and Robbery [2008-2016]")
plt.ylabel('number of years')
plt.xlabel('number of crimes')
plt.show()

# %%
df_bar_sum = df.groupby(['country'], as_index=False)['value'].sum()
df_bar_sum
# Out:
#                    country   value
# 0     Barking and Dagenham  1321.0
# 1                   Barnet  1912.0
# 2                   Bexley  1053.0
# 3                    Brent  2014.0
# 4                  Bromley  1467.0
# 5                   Camden  2542.0
# 6           City of London     6.0
# 7                  Croydon  2521.0
# 8                   Ealing  2286.0
# 9                  Enfield  1763.0
# 10               Greenwich  1586.0
# 11                 Hackney  1889.0
# 12  Hammersmith and Fulham  1527.0
# 13                Haringey  2024.0
# 14                  Harrow  1058.0
# 15                Havering  1232.0
# 16              Hillingdon  2020.0
# 17                Hounslow  1516.0
# 18               Islington  2074.0
# 19  Kensington and Chelsea  1418.0
# 20    Kingston upon Thames   650.0
# 21                 Lambeth  2698.0
# 22                Lewisham  1965.0
# 23                  Merton  1043.0
# 24                  Newham  2290.0
# 25               Redbridge  1684.0
# ...

# %%
df_bar = df_bar_sum.set_index('country')
df_bar.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Country') # add to x-label to the plot
plt.ylabel('Numbor of Crime') # add y-label to the plot
plt.title('Histogram of london_crime') # add title to the plot

plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa kota dengan kasus crime tertinggi adalah Westminster di london</span>.

# %%
df_burglary_robbery.plot(kind='bar')
plt.title('Burglary and Robbery [2008-2016]')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa tingkat kejahatan tertinggi untuk Robbery pada tahun 2011, dan Burglary pada tahun 2012</span>.

# %%
df_burglary_robbery.plot(kind='barh')
plt.title('Burglary and Robbery [2008-2016]')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas bahwa tingkat kejahatan tertinggi untuk Robbery pada tahun 2011, dan Burglary pada tahun 2012</span>.

# %% [markdown]
# Menampilkan Bar Plot Crime setiap Tahunnya

# %%
df_sum_year.plot(kind='bar',figsize=(10,7))
plt.title('LONDON CRIME 2008-2016')
plt.ylabel('number of cases')
plt.xlabel('year')

plt.annotate('',xy=(8,760000), xytext=(6,680000), arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='red', lw=2))
plt.annotate('mengalami kenaikan', xy=(6,750000))

plt.show()

# %%
df_pie = df.groupby(['country'], as_index=False)['value'].sum()
df_pie = df_pie.sort_values(by='value', ascending=False)
df_pie = df_pie.head(5)
df_pie_pre = df_pie.set_index('country')

# %%
df_pie
# Out:
#         country   value
# 32  Westminster  3830.0
# 21      Lambeth  2698.0
# 5        Camden  2542.0
# 27    Southwark  2532.0
# 7       Croydon  2521.0

# %%
df_pie_pre['value'].plot(kind='pie',
                            figsize=(5,6),
                            autopct="%1.1f%%",
                            startangle=90,
                            shadow=True);

# %% [markdown]
# <span style="color:darkblue">Di atas merupakan pie chart dari top 5 kota di london dengan kasus tertinggi selama tahun 2008 - 2016</span>.

# %% [markdown]
# BOX PLOT

# %%
df_box = df.groupby(['year'], as_index=False)['value'].sum()
df_box_pre = df_box.set_index('year')

# %%
df_box_pre.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of london crime')
plt.ylabel('Number of Crime')

plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas tingkat kejahatan tiap tahun di London selama 2008 - 2016</span>.

# %%
df_burglary_robbery.plot(kind='box', figsize=(8,6))
plt.title('box plot of major category Burglary with Robbery')
plt.ylabel('number of crime')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas adalah hasil perbandingan dari Burglary vs Robbery</span>.

# %%
df_burglary_robbery.plot(kind='box', figsize=(8,6), vert=False)
plt.title('box plot of major category Burglary with Robbery')
plt.ylabel('number of crime')
plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas adalah hasil perbandingan dari Burglary vs Robbery</span>.

# %%
df_scatter = df.groupby(['year'], as_index=False)['value'].sum()
df_scatter
# Out:
#      year   value
# 0  2008.0  6588.0
# 1  2009.0  6159.0
# 2  2010.0  6204.0
# 3  2011.0  6851.0
# 4  2012.0  6752.0
# 5  2013.0  6152.0
# 6  2014.0  5993.0
# 7  2015.0  6346.0
# 8  2016.0  6685.0

# %%
df_scatter.plot(kind='scatter', x='year', y='value', figsize=(10, 6), color='darkblue')
plt.title('London Crime')
plt.xlabel('Year')
plt.ylabel('Value')

plt.show()

# %% [markdown]
# <span style="color:darkblue">Terlihat data diatas adalah persebaran kasus crime di london selama tahun 2008 - 2016</span>.
